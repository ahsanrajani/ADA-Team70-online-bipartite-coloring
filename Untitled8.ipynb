# %% [markdown]
# <a href="https://colab.research.google.com/github/ahsanrajani/ADA-Team70-online-bipartite-coloring/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !rm -rf ~/.cache/huggingface/datasets
# !rm -rf ~/.cache/huggingface/hub

# %%
import datasets
print(datasets.__version__)
# Out:
# 3.6.0

# %%
# !git lfs install
# !git clone https://huggingface.co/datasets/muhammadnoman76/lughaat-urdu-dataset-llm
# Out:
# Git LFS initialized.
# fatal: destination path 'lughaat-urdu-dataset-llm' already exists and is not an empty directory.

# %%
# !ls lughaat-urdu-dataset-llm
# Out:
# data  README.md

# %%
import dask.dataframe as dd

# Login using e.g. `huggingface-cli login` to access this dataset
dataset = dd.read_parquet("hf://datasets/muhammadnoman76/lughaat-urdu-dataset-llm/data/train-*.parquet")

# %%
dataset.head()
# Out:
#                                        conversations
# 0  [{'content': 'تازہ ترین خبر بتائیں: عالمی بینک...
# 1  [{'content': 'تازہ ترین خبر بتائیں: مالی سال 2...
# 2  [{'content': 'تازہ ترین خبر بتائیں: جاپان کو س...
# 3  [{'content': 'تازہ ترین خبر بتائیں: برامدات 76...
# 4  [{'content': 'تازہ ترین خبر بتائیں: کے الیکٹرک...

# %%
# sample_dataset = dataset.sample(frac=0.001).compute()

# print(sample_dataset.head())

# %%
# First, convert Dask dataframe to Pandas
# df = dataset.compute()
formatted_texts = []

for row in df['conversations']:
    conversation_text = ""

    for message in row:
        content = message['content']

        conversation_text += f"<|start_header_id|>user<|end_header_id|>\n\n{content}\n\n<|eot_id|>\n"

    formatted_texts.append(conversation_text)


# Check an example:
print(formatted_texts[0])
# Out:
# <|start_header_id|>user<|end_header_id|>
#
# تازہ ترین خبر بتائیں: مشہورادا کاروں کے ہم شکل بچے
#
# <|eot_id|>
# <|start_header_id|>user<|end_header_id|>
#
# کہتے ہیں دنیا میں ایک جیسی شکل صورت والے سات لوگ پائے جاتے ہیں اس بات میں کتنی سچائی ہے اور کتنا جھوٹ یہ تو تک کوئی ثابت نہیں کر پایا لیکن دنیامیں حیرت انگیز طور پر اپنے والدین اور پاس کے لوگوں سے مشابہت رکھنے والے لوگ موجود ہیں ہم کو بھارت کے ان فنکاروں کے حوالے سے بتائیں گے جو دوسروںسے حیرت انگیز مشابہت رکھتے ہیں اسمیتا پاٹیل اور ان کے بیٹے پرتیک ببرسری دیوی بیٹی خوشی کپورسیف علی خان بیٹا ابراہم خاناداکارہ ببیتا بیٹی کرشمہ کپورامریتا سنگھ بیٹی سارہ خانشاہ رخ خان بیٹا ریان خانرشی کپور بیٹی ردھما کپورراکیش روشنبیٹا رتیک روشنارباز خان بیٹا رہان خانٹوئنیکل کھنناڈمپل کباڈیہاداکارہ سونی رضاعالیہ بھٹ
#
# <|eot_id|>

# %%
# !pip install unsloth
from unsloth import FastLanguageModel
import torch

fourbit_models = [
    # 4bit dynamic quants for superior accuracy and low memory use
    "unsloth/gemma-3-4b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-12b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-27b-it-unsloth-bnb-4bit",
    # Qwen3 new models
    "unsloth/Qwen3-4B-unsloth-bnb-4bit",
    "unsloth/Qwen3-8B-unsloth-bnb-4bit",
    # Other very popular models!
    "unsloth/Llama-3.1-8B",
    "unsloth/Llama-3.2-3B",
    "unsloth/Llama-3.3-70B",
    "unsloth/mistral-7b-instruct-v0.3",
    "unsloth/Phi-4",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-3B-Instruct",
    max_seq_length = 2048, # Choose any for long context!
    load_in_4bit = True,  # 4 bit quantization to reduce memory
    load_in_8bit = False, # [NEW!] A bit more accurate, uses 2x memory
    full_finetuning = False, # [NEW!] We have full finetuning now!
    # token = "hf_...", # use one if using gated models
)
# Out:
# ==((====))==  Unsloth 2025.5.9: Fast Llama patching. Transformers: 4.52.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.3.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.30. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.35G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)

# %%
from trl import SFTTrainer, SFTConfig
import datasets # Import the datasets library

# Assuming formatted_texts is your list of strings
# Convert the list of strings into a datasets.Dataset object
train_dataset = datasets.Dataset.from_dict({"text": formatted_texts})

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = train_dataset, # Use the created dataset object
    eval_dataset = None, # Can set up evaluation!
    args = SFTConfig(
        dataset_text_field = "text",
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 8, # Use GA to mimic batch size!
        warmup_steps = 5,
        max_steps = 60,
        learning_rate = 2e-4,
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        report_to = "none", # Use this for WandB etc
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/10385 [00:00<?, ? examples/s]

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.741 GB.
# 5.686 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 10,385 | Num Epochs = 1 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 8 x 1) = 8
#  "-____-"     Trainable parameters = 24,313,856/3,000,000,000 (0.81% trained)
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 09:56, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.950200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.062400</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.941400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.836200</td>
#     </tr>
# ...

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 607.3817 seconds used for training.
# 10.12 minutes used for training.
# Peak reserved memory = 5.686 GB.
# Peak reserved memory for training = 0.0 GB.
# Peak reserved memory % of max memory = 38.573 %.
# Peak reserved memory for training % of max memory = 0.0 %.

# %%
messages = [
    {"role": "user", "content": "ازہ ترین خبر بتائیں: مشہورادا کاروں کے ہم شکل بچے?"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(input_ids = inputs, streamer = text_streamer,
                   max_new_tokens = 256, temperature = 0.1)
# Out:
# لاہور اردو پوائنٹ اخبارتازہ ترین 14 اگست2018ء پاکستان کے مشہور اداکاروں میں سے ایک شاہد خان نے اپنے بچوں کے ساتھ کھیلتے ہوئے دیکھا کہ وہ بچے ہم شکل کے بچے ہیں
#
# <|eot_id|>
